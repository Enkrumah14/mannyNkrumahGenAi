# %% [markdown]
# <a href="https://colab.research.google.com/github/Enkrumah14/mannyNkrumahGenAi/blob/main/Problem1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Libraries
import os
import glob
import time
from fractions import Fraction
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, losses, callbacks
import music21

# Parameters
PARSE_MIDI_FILES = True
PARSED_DATA_PATH = "/content/output"
DATASET_REPETITIONS = 1
SEQ_LEN = 50
EMBEDDING_DIM = 256
KEY_DIM = 256
N_HEADS = 5
DROPOUT_RATE = 0.3
FEED_FORWARD_DIM = 256
LOAD_MODEL = False
EPOCHS = 100
BATCH_SIZE = 256
GENERATE_LEN = 50

# Function to parse MIDI files
def parse_midi_files(file_list, parser, seq_len, parsed_data_path):
    notes, durations = [], []
    for file in file_list:
        try:
            score = parser.parse(file)
            flat_score = score.flat.notes
            file_notes, file_durations = [], []
            for element in flat_score:
                if isinstance(element, music21.note.Note):
                    if element.nameWithOctave:  # Ensure note is valid
                        file_notes.append(element.nameWithOctave)
                        file_durations.append(str(element.quarterLength))
                elif isinstance(element, music21.note.Rest):
                    file_notes.append("rest")
                    file_durations.append(str(element.quarterLength))
            notes.extend(file_notes[:seq_len])
            durations.extend(file_durations[:seq_len])
        except Exception as e:
            print(f"Error parsing {file}: {e}")

    # Filter out invalid entries and replace `[UNK]` with defaults
    notes = [note for note in notes if note.strip() and note != "[UNK]"]
    durations = [
        duration if duration.strip() and duration != "[UNK]" else "0.25"
        for duration in durations
    ]
    return notes, durations

# Function to generate a MIDI note
def get_midi_note(note, duration):
    try:
        # Convert fractional durations to float
        duration_value = float(Fraction(duration))
    except ValueError:
        print(f"Invalid duration: {duration}, defaulting to 0.25")
        duration_value = 0.25  # Default to a quarter note if conversion fails

    if note == "rest":
        return music21.note.Rest(quarterLength=duration_value)
    elif note.strip() and note != "[UNK]":  # Ensure note is valid and not `[UNK]`
        try:
            return music21.note.Note(note, quarterLength=duration_value)
        except music21.pitch.PitchException:
            print(f"Invalid note: {note}, skipping.")
            return None
    else:
        print(f"Empty or unknown note encountered, skipping.")
        return None

# Sine positional encoding
class SinePositionEncoding(layers.Layer):
    def __init__(self):
        super().__init__()

    def call(self, inputs):
        seq_len = tf.shape(inputs)[1]
        embed_dim = tf.shape(inputs)[2]
        pos = tf.cast(tf.range(seq_len)[..., tf.newaxis], tf.float32)
        i = tf.cast(tf.range(embed_dim)[tf.newaxis, ...], tf.float32)
        angles = pos / tf.pow(10000.0, (2 * (i // 2)) / tf.cast(embed_dim, tf.float32))
        encoding = tf.where(tf.cast(i % 2, tf.bool), tf.cos(angles), tf.sin(angles))
        return inputs + encoding

# Data Preparation
file_list = glob.glob(f"{PARSED_DATA_PATH}/*.mid")
print(f"Found {len(file_list)} MIDI files")

if PARSE_MIDI_FILES:
    notes, durations = parse_midi_files(file_list, music21.converter, SEQ_LEN + 1, PARSED_DATA_PATH)
else:
    notes, durations = [], []

# Tokenization
def create_dataset(elements):
    elements = [str(e) for e in elements]
    ds = (
        tf.data.Dataset.from_tensor_slices(elements)
        .batch(BATCH_SIZE, drop_remainder=True)
        .shuffle(1000)
    )
    vectorize_layer = layers.TextVectorization(standardize=None, output_mode="int")
    vectorize_layer.adapt(ds)
    vocab = vectorize_layer.get_vocabulary()
    return ds, vectorize_layer, vocab

notes_seq_ds, notes_vectorize_layer, notes_vocab = create_dataset(notes)
durations_seq_ds, durations_vectorize_layer, durations_vocab = create_dataset(durations)
seq_ds = tf.data.Dataset.zip((notes_seq_ds, durations_seq_ds))

# Dataset Preparation for Training
def prepare_inputs(notes, durations):
    notes = tf.expand_dims(notes, -1)
    durations = tf.expand_dims(durations, -1)
    tokenized_notes = notes_vectorize_layer(notes)
    tokenized_durations = durations_vectorize_layer(durations)
    x = (tokenized_notes[:, :-1], tokenized_durations[:, :-1])
    y = (tokenized_notes[:, 1:], tokenized_durations[:, 1:])
    return x, y

ds = seq_ds.map(prepare_inputs).repeat(DATASET_REPETITIONS)

# Causal Attention Mask
def causal_attention_mask(batch_size, n_dest, n_src, dtype):
    i = tf.range(n_dest)[:, None]
    j = tf.range(n_src)
    mask = i >= j - n_src + n_dest
    mask = tf.cast(mask, dtype)
    mask = tf.reshape(mask, [1, n_dest, n_src])
    mult = tf.concat([tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)], 0)
    return tf.tile(mask, mult)

# Transformer Block
class TransformerBlock(layers.Layer):
    def __init__(self, num_heads, key_dim, embed_dim, ff_dim, name, dropout_rate=DROPOUT_RATE):
        super().__init__(name=name)
        self.attn = layers.MultiHeadAttention(num_heads, key_dim, output_shape=embed_dim)
        self.dropout_1 = layers.Dropout(dropout_rate)
        self.ln_1 = layers.LayerNormalization(epsilon=1e-6)
        self.ffn_1 = layers.Dense(ff_dim, activation="relu")
        self.ffn_2 = layers.Dense(embed_dim)
        self.dropout_2 = layers.Dropout(dropout_rate)
        self.ln_2 = layers.LayerNormalization(epsilon=1e-6)

    def call(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, seq_len = input_shape[0], input_shape[1]
        causal_mask = causal_attention_mask(batch_size, seq_len, seq_len, tf.bool)
        attention_output, attention_scores = self.attn(
            inputs, inputs, attention_mask=causal_mask, return_attention_scores=True
        )
        attention_output = self.dropout_1(attention_output)
        out1 = self.ln_1(inputs + attention_output)
        ffn_output = self.dropout_2(self.ffn_2(self.ffn_1(out1)))
        return self.ln_2(out1 + ffn_output), attention_scores

# Token and Position Embedding
class TokenAndPositionEmbedding(layers.Layer):
    def __init__(self, vocab_size, embed_dim):
        super().__init__()
        self.token_emb = layers.Embedding(
            input_dim=vocab_size, output_dim=embed_dim, embeddings_initializer="he_uniform"
        )
        self.pos_emb = SinePositionEncoding()

    def call(self, x):
        token_embeddings = self.token_emb(x)
        positions = self.pos_emb(token_embeddings)
        return token_embeddings + positions

# Build the Model
note_inputs = layers.Input(shape=(None,), dtype=tf.int32)
durations_inputs = layers.Input(shape=(None,), dtype=tf.int32)
note_embeddings = TokenAndPositionEmbedding(len(notes_vocab), EMBEDDING_DIM // 2)(note_inputs)
duration_embeddings = TokenAndPositionEmbedding(len(durations_vocab), EMBEDDING_DIM // 2)(durations_inputs)
embeddings = layers.Concatenate()([note_embeddings, duration_embeddings])
x, attention_scores = TransformerBlock(
    N_HEADS, KEY_DIM, EMBEDDING_DIM, FEED_FORWARD_DIM, name="attention"
)(embeddings)
note_outputs = layers.Dense(len(notes_vocab), activation="softmax", name="note_outputs")(x)
duration_outputs = layers.Dense(len(durations_vocab), activation="softmax", name="duration_outputs")(x)
model = models.Model(inputs=[note_inputs, durations_inputs], outputs=[note_outputs, duration_outputs])
model.compile(optimizer="adam", loss=[
    losses.SparseCategoricalCrossentropy(), losses.SparseCategoricalCrossentropy()
])
model.summary()

# Music Generator Callback
class MusicGenerator(callbacks.Callback):
    def __init__(self, notes_vocab, durations_vocab, output_path="/content/output"):
        self.index_to_note = {idx: note for idx, note in enumerate(notes_vocab)}
        self.index_to_duration = {idx: duration for idx, duration in enumerate(durations_vocab)}
        self.output_path = output_path
        os.makedirs(output_path, exist_ok=True)

    def generate(self, start_notes, start_durations, max_tokens=GENERATE_LEN, temperature=0.5):
        notes = [self.index_to_note.get(int(x), "rest") for x in start_notes]
        durations = [self.index_to_duration.get(int(x), "0.25") for x in start_durations]

        midi_stream = music21.stream.Stream()
        midi_stream.append(music21.clef.BassClef())

        for note, duration in zip(notes, durations):
            midi_note = get_midi_note(note, duration)
            if midi_note:
                midi_stream.append(midi_note)

        for _ in range(max_tokens):
            x1 = tf.convert_to_tensor([start_notes])
            x2 = tf.convert_to_tensor([start_durations])
            pred_notes, pred_durations = model.predict([x1, x2], verbose=0)

            pred_note_idx = tf.random.categorical(tf.math.log(pred_notes[0]), num_samples=1).numpy()[0, 0]
            pred_duration_idx = tf.random.categorical(tf.math.log(pred_durations[0]), num_samples=1).numpy()[0, 0]

            start_notes.append(pred_note_idx)
            start_durations.append(pred_duration_idx)

            note = self.index_to_note.get(pred_note_idx, "rest")
            duration = self.index_to_duration.get(pred_duration_idx, "0.25")
            midi_note = get_midi_note(note, duration)
            if midi_note:
                midi_stream.append(midi_note)

        return midi_stream

    def on_epoch_end(self, epoch, logs=None):
        start_notes = [int(notes_vectorize_layer(["C4"]).numpy().item())]
        start_durations = [int(durations_vectorize_layer(["0.25"]).numpy().item())]

        midi_stream = self.generate(start_notes, start_durations)
        timestamp = time.strftime("%Y%m%d-%H%M%S")
        file_path = os.path.join(self.output_path, f"output-{timestamp}-epoch{epoch}.mid")
        midi_stream.write("midi", fp=file_path)
        print(f"Exported MIDI file for epoch {epoch}: {file_path}")

# Initialize the Music Generator Callback
music_generator = MusicGenerator(notes_vocab, durations_vocab)

# Train the Model with the Callback
model.fit(ds, epochs=EPOCHS, callbacks=[music_generator])
# Out:
# Found 36 MIDI files
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_14            │ (None, None)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_15            │ (None, None)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ token_and_position_embed… │ (None, None, 128)      │          4,864 │ input_layer_14[0][0]   │
# │ (TokenAndPositionEmbeddi… │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ token_and_position_embed… │ (None, None, 128)      │          1,536 │ input_layer_15[0][0]   │
# │ (TokenAndPositionEmbeddi… │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_7             │ (None, None, 256)      │              0 │ token_and_position_em… │
# │ (Concatenate)             │                        │                │ token_and_position_em… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ attention                 │ [(None, None, 256),    │      1,447,424 │ concatenate_7[0][0]    │
# │ (TransformerBlock)        │ (None, 5, None, None)] │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ note_outputs (Dense)      │ (None, None, 38)       │          9,766 │ attention[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ duration_outputs (Dense)  │ (None, None, 12)       │          3,084 │ attention[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,466,674 (5.59 MB)
#  Trainable params: 1,466,674 (5.59 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 0: /content/output/output-20241207-023436-epoch0.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 208s 34s/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 2/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 1: /content/output/output-20241207-023439-epoch1.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 535ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 3/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 2: /content/output/output-20241207-023442-epoch2.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 514ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 4/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 3: /content/output/output-20241207-023446-epoch3.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 516ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 5/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 4: /content/output/output-20241207-023449-epoch4.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 510ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 6/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanEmpty or unknown note encountered, skipping.
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 5: /content/output/output-20241207-023452-epoch5.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 507ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 7/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 6: /content/output/output-20241207-023455-epoch6.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 586ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 8/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 7: /content/output/output-20241207-023459-epoch7.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 541ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 9/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 8: /content/output/output-20241207-023502-epoch8.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 558ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 10/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 9: /content/output/output-20241207-023505-epoch9.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 548ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 11/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Exported MIDI file for epoch 10: /content/output/output-20241207-023509-epoch10.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 547ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 12/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 11: /content/output/output-20241207-023512-epoch11.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 544ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 13/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Empty or unknown note encountered, skipping.
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 12: /content/output/output-20241207-023515-epoch12.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 585ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 14/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 13: /content/output/output-20241207-023519-epoch13.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 580ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 15/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 14: /content/output/output-20241207-023522-epoch14.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 558ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 16/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanEmpty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 15: /content/output/output-20241207-023526-epoch15.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 525ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 17/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 16: /content/output/output-20241207-023529-epoch16.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 529ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 18/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 17: /content/output/output-20241207-023532-epoch17.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 545ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 19/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 18: /content/output/output-20241207-023536-epoch18.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 566ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 20/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 19: /content/output/output-20241207-023539-epoch19.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 569ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 21/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Exported MIDI file for epoch 20: /content/output/output-20241207-023542-epoch20.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 546ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 22/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 21: /content/output/output-20241207-023546-epoch21.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 531ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 23/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 22: /content/output/output-20241207-023549-epoch22.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 528ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 24/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 23: /content/output/output-20241207-023552-epoch23.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 545ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 25/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanEmpty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 24: /content/output/output-20241207-023555-epoch24.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 553ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 26/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 25: /content/output/output-20241207-023559-epoch25.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 523ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 27/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 26: /content/output/output-20241207-023602-epoch26.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 524ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 28/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 27: /content/output/output-20241207-023605-epoch27.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 517ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 29/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 28: /content/output/output-20241207-023608-epoch28.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 527ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 30/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 29: /content/output/output-20241207-023611-epoch29.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 532ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 31/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 30: /content/output/output-20241207-023615-epoch30.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 547ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 32/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 31: /content/output/output-20241207-023618-epoch31.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 527ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 33/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Exported MIDI file for epoch 32: /content/output/output-20241207-023621-epoch32.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 519ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 34/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 33: /content/output/output-20241207-023625-epoch33.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 601ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 35/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 34: /content/output/output-20241207-023628-epoch34.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 531ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 36/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 35: /content/output/output-20241207-023631-epoch35.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 526ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 37/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 36: /content/output/output-20241207-023634-epoch36.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 536ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 38/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 37: /content/output/output-20241207-023638-epoch37.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 546ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 39/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 38: /content/output/output-20241207-023641-epoch38.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 535ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 40/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 39: /content/output/output-20241207-023644-epoch39.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 533ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 41/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 40: /content/output/output-20241207-023647-epoch40.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 530ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 42/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 41: /content/output/output-20241207-023651-epoch41.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 525ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 43/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 42: /content/output/output-20241207-023654-epoch42.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 538ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 44/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 43: /content/output/output-20241207-023657-epoch43.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 518ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 45/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 44: /content/output/output-20241207-023700-epoch44.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 530ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 46/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 45: /content/output/output-20241207-023704-epoch45.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 533ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 47/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 46: /content/output/output-20241207-023707-epoch46.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 528ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 48/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Exported MIDI file for epoch 47: /content/output/output-20241207-023710-epoch47.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 519ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 49/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanEmpty or unknown note encountered, skipping.
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 48: /content/output/output-20241207-023713-epoch48.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 538ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 50/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 49: /content/output/output-20241207-023716-epoch49.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 518ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 51/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 50: /content/output/output-20241207-023720-epoch50.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 523ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 52/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# ...
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Exported MIDI file for epoch 82: /content/output/output-20241207-023901-epoch82.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 513ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 84/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 83: /content/output/output-20241207-023904-epoch83.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 518ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 85/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 84: /content/output/output-20241207-023908-epoch84.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 514ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 86/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 85: /content/output/output-20241207-023911-epoch85.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 561ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 87/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 86: /content/output/output-20241207-023914-epoch86.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 533ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 88/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 87: /content/output/output-20241207-023917-epoch87.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 537ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 89/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 88: /content/output/output-20241207-023921-epoch88.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 528ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 90/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 89: /content/output/output-20241207-023924-epoch89.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 514ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 91/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 90: /content/output/output-20241207-023927-epoch90.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 523ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 92/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 91: /content/output/output-20241207-023930-epoch91.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 533ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 93/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 92: /content/output/output-20241207-023933-epoch92.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 522ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 94/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanEmpty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 93: /content/output/output-20241207-023937-epoch93.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 518ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 95/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 94: /content/output/output-20241207-023940-epoch94.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 524ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 96/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Exported MIDI file for epoch 95: /content/output/output-20241207-023943-epoch95.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 532ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 97/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 96: /content/output/output-20241207-023946-epoch96.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 517ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 98/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: , defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 97: /content/output/output-20241207-023949-epoch97.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 517ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 99/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 98: /content/output/output-20241207-023952-epoch98.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 514ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan
# Epoch 100/100
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nanInvalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Empty or unknown note encountered, skipping.
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Invalid duration: [UNK], defaulting to 0.25
# Exported MIDI file for epoch 99: /content/output/output-20241207-023956-epoch99.mid
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 522ms/step - duration_outputs_loss: nan - loss: nan - note_outputs_loss: nan

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# /content/bach_cello_suites.zip
